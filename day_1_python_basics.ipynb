# %% [markdown]
# <a href="https://colab.research.google.com/github/Idhirap/python-learning/blob/main/day_1_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Python Output

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("salman khan")
# Out:
# salman khan

# %%
print(salman khan)
# Out:
#   File "/tmp/ipykernel_1532/1115953987.py", line 1
#     print(salman khan)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1532/1349525255.py in <cell line: 0>()
# ----> 1 sjg
#
# NameError: name 'sjg' is not defined

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %%
print("heelo",1,4.3,True)
# Out:
# heelo 1 4.3 True

# %%
print("hello",1,4.5,True,sep='/')
# Out:
# hello/1/4.5/True

# %%
print("hello","my",sep="''")
# Out:
# hello''my

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello',end='-')
print('world')
# Out:
# hello-world

# %% [markdown]
# #2. Data Types

# %%
#Integer
print(8)
1*10^309
print(1e309)
print(1e308)
# Out:
# 8
# inf
# 1e+308

# %%
#Decimal/Float
print(8.55)
print(1.7e309)
print(1.7e308)
# Out:
# 8.55
# inf
# 1.7e+308

# %%
#Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#Text/String
print("Hello World")
# Out:
# Hello World

# %%
#complex
print(5+6j)
# Out:
# (5+6j)

# %%
#List->C->Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#Dictionary
print({"name":"Paridhi","gender":"female",'weight':54})
# Out:
# {'name': 'Paridhi', 'gender': 'female', 'weight': 54}

# %%
#type
type([1,2,3])
type(3)
type(3.5)
# Out:
# float

# %%
type("gey")
# Out:
# str

# %%
type(5+9j)
# Out:
# complex
