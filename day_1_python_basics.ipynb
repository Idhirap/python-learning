# %% [markdown]
# <a href="https://colab.research.google.com/github/Idhirap/python-learning/blob/main/day_1_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Python Output

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("salman khan")
# Out:
# salman khan

# %%
print(salman khan)
# Out:
#   File "/tmp/ipykernel_1532/1115953987.py", line 1
#     print(salman khan)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1532/1349525255.py in <cell line: 0>()
# ----> 1 sjg
#
# NameError: name 'sjg' is not defined

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %%
print("heelo",1,4.3,True)
# Out:
# heelo 1 4.3 True

# %%
print("hello",1,4.5,True,sep='/')
# Out:
# hello/1/4.5/True

# %%
print("hello","my",sep="''")
# Out:
# hello''my

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello',end='-')
print('world')
# Out:
# hello-world

# %% [markdown]
# #2. Data Types

# %%
#Integer
print(8)
1*10^309
print(1e309)
print(1e308)
# Out:
# 8
# inf
# 1e+308

# %%
#Decimal/Float
print(8.55)
print(1.7e309)
print(1.7e308)
# Out:
# 8.55
# inf
# 1.7e+308

# %%
#Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#Text/String
print("Hello World")
# Out:
# Hello World

# %%
#complex
print(5+6j)
# Out:
# (5+6j)

# %%
#List->C->Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#Dictionary
print({"name":"Paridhi","gender":"female",'weight':54})
# Out:
# {'name': 'Paridhi', 'gender': 'female', 'weight': 54}

# %%
#type
type([1,2,3])
type(3)
type(3.5)
# Out:
# float

# %%
type("gey")
# Out:
# str

# %%
type(5+9j)
# Out:
# complex

# %% [markdown]
# #3. Variables

# %%
#creating a variable in python
name = 'nia'
print(name)

a = 5
b = 6
print(a+b)
# Out:
# nia
# 11

# %%
#Static Vs Dynamic Typing
#Static
int  a = 5
#Dynamic
a = 7
# Out:
#   File "/tmp/ipykernel_548/1614995767.py", line 3
#     int  a = 5
#          ^
# SyntaxError: invalid syntax

# %%
#Static Vs Dynamic Binding
#int a = 5 # always integerdatatype
#Dynamic
a = 5
print(a)
a='par'
print(a)
a=True
print(a)
# Out:
# 5
# par
# True

# %%
#Stylish declaration techniques
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
a=b=c = 5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# # Comments

# %%
#this is a comment
#second line
a = 4 #like this
b = 6
#printing
print(a+b)
# Out:
# 10

# %% [markdown]
# # 4. Keywords & Identifiers

# %%
#Keywords

# %%
#Identifiers
#fucntion/Variables/classes
#can't start with a digit
name1 ='pari'
print(name1)
#only special char ->_
first_name='pari'
print(first_name)
_pia='pari'
print(_pia)
_ = 'rahul'
print(_)
#identifiers can't be keywords
# Out:
# pari
# pari
# pari
# rahul

# %% [markdown]
# # 5.User Input

# %%
#Static Vs Dynamic
input("Enter email:")
# Out:
# Enter email:2piert@gmail.com
# '2piert@gmail.com'

# %%
fnum = int(input("Enter first num"))
snum = int(input("enter second num"))
type(snum)
print(fnum,snum)
print(type(fnum),type(snum))
result = fnum +snum
print(result)
print(type(fnum))
# Out:
# Enter first num56
# enter second num7
# 56 7
# <class 'int'> <class 'int'>
# 63
# <class 'int'>

# %% [markdown]
# # 6. Type Conversion6

# %%
#Implicit Vs Explicit
print(5+5.6)
print(type(5),type(5.6))
print(4+'4')
# Out:
# 10.6
# <class 'int'> <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_330/3346039336.py in <cell line: 0>()
#       2 print(5+5.6)
#       3 print(type(5),type(5.6))
# ----> 4 print(4+'4')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#Explicit
#str->int
int('5')
#int(4+5j)

#int to str
str(4)

#float
float(4)
# Out:
# 4.0

# %% [markdown]
# # 7. Literal

# %%
a = 0b1010 #binary literal
print(a)
# Out:
# 10

# %%
b = 100 #decimal literal
c = 0o310 #Octal Literal

print(c)
d= 0x12c #hexadecimal literal
print(d)
# Out:
# 200
# 300

# %%
#Float Literal
float_1 = 10.5
float_2 = 1.5e3
print(float_2)
float_3 = 1.5e-3 #1.5*10^-3
print(float_3)

#complex literal
x=3.14j
print(x.real,x.imag)
# Out:
# 1500.0
# 0.0015
# 0.0 3.14

# %%
char = "C"
multiline_str ="""This is a multiline string in
diff lines with more than single
code of line."""
unicode = u"\U0001F600\U0001F606\U0001f923"
raw_str = r"raw \n string"
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# C
# This is a multiline string in
# diff lines with more than single
# code of line.
# 😀😆🤣
# raw \n string

# %%
a = True +4
b = False+ 10
print("a:",a)
print("b:",b)
# Out:
# a: 5
# b: 10

# %%
k = None
a= 2
b=3
print("prog executed")
# Out:
# prog executed

# %% [markdown]
# # 8. Operators
